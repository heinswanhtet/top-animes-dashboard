# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %% [markdown]
# ## Introduction
#
# The main goal of this project is to build a web app of **Top 10 Animes Across Years & Recommendations**. This app can guide and help people who are interested in japanese animations and are trying to start watching.
#
# In order to build the app, animes data are needed. In this part, we will perform **EDA** process on the collected data.
#
#
# *Note: During throughout the project, Anime means Japanese Animation Cartoon.*

# %% [markdown]
# # Imports

# %% [markdown]
# ### Import necessary libraries and packages
#
# To start process EDA on the data, first, relevant Python libraries and modules are imported.

# %%
import pandas as pd
import numpy as np
import ast

# setting max columns display to None in order to display all columns in the data
pd.set_option('display.max_columns', None)

# %% [markdown]
# ### Load the dataset

# %% [markdown]
# The data contains details about animes like title, score, genres, studio, year, season, etc.
#
# The dataset `anime_data_2006_2022.csv` is loaded as `animes`.

# %%
animes = pd.read_csv('./anime_data_2006_2022.csv')

# %% [markdown]
# # Data Discovering

# %% [markdown]
# Let's view first five rows from `animes`

# %%
animes.head()
# Out:
#    mal_id                                                url  approved  \
# 0     853  https://myanimelist.net/anime/853/Ouran_Koukou...      True
# 1     918          https://myanimelist.net/anime/918/Gintama      True
# 2     889     https://myanimelist.net/anime/889/Black_Lagoon      True
# 3     849  https://myanimelist.net/anime/849/Suzumiya_Har...      True
# 4     934  https://myanimelist.net/anime/934/Higurashi_no...      True
#
#                                               titles  \
# 0  [{'type': 'Default', 'title': 'Ouran Koukou Ho...
# 1  [{'type': 'Default', 'title': 'Gintama'}, {'ty...
# 2  [{'type': 'Default', 'title': 'Black Lagoon'},...
# 3  [{'type': 'Default', 'title': 'Suzumiya Haruhi...
# 4  [{'type': 'Default', 'title': 'Higurashi no Na...
#
#                         title                      title_english  \
# 0      Ouran Koukou Host Club        Ouran High School Host Club
# 1                     Gintama                            Gintama
# 2                Black Lagoon                       Black Lagoon
# 3  Suzumiya Haruhi no Yuuutsu  The Melancholy of Haruhi Suzumiya
# 4   Higurashi no Naku Koro ni           Higurashi: When They Cry
#
#   title_japanese                                     title_synonyms type  \
# 0       桜蘭高校ホスト部  ['Ohran Koko Host Club', 'Ouran Koukou Hosutob...   TV
# 1             銀魂  ['Gin Tama', 'Silver Soul', 'Yorinuki Gintama-...   TV
# 2   BLACK LAGOON                                                 []   TV
# 3       涼宮ハルヒの憂鬱                     ['Suzumiya Haruhi no Yuuutsu']   TV
# 4      ひぐらしのなく頃に  ['When the Cicadas Cry', 'The Moment the Cicad...   TV
#
#          source  episodes           status  airing       duration  \
# 0         Manga      26.0  Finished Airing   False  23 min per ep
# 1         Manga     201.0  Finished Airing   False  24 min per ep
# 2         Manga      12.0  Finished Airing   False  23 min per ep
# 3   Light novel      14.0  Finished Airing   False  23 min per ep
# 4  Visual novel      26.0  Finished Airing   False  24 min per ep
#
#                            rating  score  scored_by   rank  popularity  \
# 0       PG-13 - Teens 13 or older   8.16   672279.0  413.0         128
# 1       PG-13 - Teens 13 or older   8.94   391827.0   15.0         139
# 2  R - 17+ (violence & profanity)   8.03   487522.0  573.0         155
# 3       PG-13 - Teens 13 or older   7.83   475447.0  888.0         179
# 4  R - 17+ (violence & profanity)   7.88   391899.0  809.0         229
#
#    members  favorites                                           synopsis  \
# 0  1110503      34094  Haruhi Fujioka is a studious girl who has rece...
# 1  1052162      58905  Edo is a city that was home to the vigor and a...
# 2   993437      18516  Salaryman Rokurou Okajima spends his days tryi...
# 3   909771      15321  If a survey were conducted to see if people be...
# 4   797940      21247  Keiichi Maebara has just moved to the quiet li...
#
#                                           background  season    year  \
# 0  In addition to this anime and the source manga...  spring  2006.0
# 1  Several games based on Gintama have been relea...  spring  2006.0
# 2  Black Lagoon was released on DVD by Geneon Ent...  spring  2006.0
# 3  Suzumiya Haruhi no Yuuutsu aired in a nonlinea...  spring  2006.0
# 4  Geneon Entertainment USA initially licensed an...  spring  2006.0
#
#                                            producers  \
# 0  [{'mal_id': 29, 'type': 'anime', 'name': 'VAP'...
# 1  [{'mal_id': 16, 'type': 'anime', 'name': 'TV T...
# 2  [{'mal_id': 31, 'type': 'anime', 'name': 'Gene...
# 3  [{'mal_id': 104, 'type': 'anime', 'name': 'Lan...
# 4  [{'mal_id': 31, 'type': 'anime', 'name': 'Gene...
#
#                                            licensors  \
# 0  [{'mal_id': 102, 'type': 'anime', 'name': 'Fun...
# 1  [{'mal_id': 376, 'type': 'anime', 'name': 'Sen...
# 2  [{'mal_id': 102, 'type': 'anime', 'name': 'Fun...
# 3  [{'mal_id': 102, 'type': 'anime', 'name': 'Fun...
# 4  [{'mal_id': 376, 'type': 'anime', 'name': 'Sen...
#
#                                              studios  \
# 0  [{'mal_id': 4, 'type': 'anime', 'name': 'Bones...
# 1  [{'mal_id': 14, 'type': 'anime', 'name': 'Sunr...
# 2  [{'mal_id': 11, 'type': 'anime', 'name': 'Madh...
# 3  [{'mal_id': 2, 'type': 'anime', 'name': 'Kyoto...
# 4  [{'mal_id': 37, 'type': 'anime', 'name': 'Stud...
#
#                                               genres explicit_genres  \
# 0  [{'mal_id': 4, 'type': 'anime', 'name': 'Comed...              []
# 1  [{'mal_id': 1, 'type': 'anime', 'name': 'Actio...              []
# 2  [{'mal_id': 1, 'type': 'anime', 'name': 'Actio...              []
# 3  [{'mal_id': 46, 'type': 'anime', 'name': 'Awar...              []
# 4  [{'mal_id': 14, 'type': 'anime', 'name': 'Horr...              []
#
#                                               themes  \
# 0  [{'mal_id': 81, 'type': 'anime', 'name': 'Cros...
# 1  [{'mal_id': 57, 'type': 'anime', 'name': 'Gag ...
# 2  [{'mal_id': 50, 'type': 'anime', 'name': 'Adul...
# 3  [{'mal_id': 23, 'type': 'anime', 'name': 'Scho...
# 4  [{'mal_id': 58, 'type': 'anime', 'name': 'Gore...
#
#                                         demographics  \
# 0  [{'mal_id': 25, 'type': 'anime', 'name': 'Shou...
# 1  [{'mal_id': 27, 'type': 'anime', 'name': 'Shou...
# 2  [{'mal_id': 42, 'type': 'anime', 'name': 'Sein...
# 3                                                 []
# 4                                                 []
#
#                                 images.jpg.image_url  \
# 0  https://cdn.myanimelist.net/images/anime/2/719...
# 1  https://cdn.myanimelist.net/images/anime/10/73...
# 2  https://cdn.myanimelist.net/images/anime/1906/...
# 3  https://cdn.myanimelist.net/images/anime/1470/...
# 4  https://cdn.myanimelist.net/images/anime/12/19...
#
#                           images.jpg.small_image_url  \
# 0  https://cdn.myanimelist.net/images/anime/2/719...
# 1  https://cdn.myanimelist.net/images/anime/10/73...
# 2  https://cdn.myanimelist.net/images/anime/1906/...
# 3  https://cdn.myanimelist.net/images/anime/1470/...
# 4  https://cdn.myanimelist.net/images/anime/12/19...
#
#                           images.jpg.large_image_url  \
# 0  https://cdn.myanimelist.net/images/anime/2/719...
# 1  https://cdn.myanimelist.net/images/anime/10/73...
# 2  https://cdn.myanimelist.net/images/anime/1906/...
# 3  https://cdn.myanimelist.net/images/anime/1470/...
# 4  https://cdn.myanimelist.net/images/anime/12/19...
#
#                                images.webp.image_url  \
# 0  https://cdn.myanimelist.net/images/anime/2/719...
# 1  https://cdn.myanimelist.net/images/anime/10/73...
# 2  https://cdn.myanimelist.net/images/anime/1906/...
# 3  https://cdn.myanimelist.net/images/anime/1470/...
# 4  https://cdn.myanimelist.net/images/anime/12/19...
#
#                          images.webp.small_image_url  \
# 0  https://cdn.myanimelist.net/images/anime/2/719...
# 1  https://cdn.myanimelist.net/images/anime/10/73...
# 2  https://cdn.myanimelist.net/images/anime/1906/...
# 3  https://cdn.myanimelist.net/images/anime/1470/...
# 4  https://cdn.myanimelist.net/images/anime/12/19...
#
#                          images.webp.large_image_url trailer.youtube_id  \
# 0  https://cdn.myanimelist.net/images/anime/2/719...        NcC5VCE2Its
# 1  https://cdn.myanimelist.net/images/anime/10/73...                NaN
# 2  https://cdn.myanimelist.net/images/anime/1906/...        d4EbGC7fKnQ
# 3  https://cdn.myanimelist.net/images/anime/1470/...                NaN
# 4  https://cdn.myanimelist.net/images/anime/12/19...                NaN
#
#                                    trailer.url  \
# 0  https://www.youtube.com/watch?v=NcC5VCE2Its
# 1                                          NaN
# 2  https://www.youtube.com/watch?v=d4EbGC7fKnQ
# 3                                          NaN
# 4                                          NaN
#
#                                    trailer.embed_url  \
# 0  https://www.youtube.com/embed/NcC5VCE2Its?enab...
# 1                                                NaN
# 2  https://www.youtube.com/embed/d4EbGC7fKnQ?enab...
# 3                                                NaN
# 4                                                NaN
#
#                             trailer.images.image_url  \
# 0  https://img.youtube.com/vi/NcC5VCE2Its/default...
# 1                                                NaN
# 2  https://img.youtube.com/vi/d4EbGC7fKnQ/default...
# 3                                                NaN
# 4                                                NaN
#
#                       trailer.images.small_image_url  \
# 0  https://img.youtube.com/vi/NcC5VCE2Its/sddefau...
# 1                                                NaN
# 2  https://img.youtube.com/vi/d4EbGC7fKnQ/sddefau...
# 3                                                NaN
# 4                                                NaN
#
#                      trailer.images.medium_image_url  \
# 0  https://img.youtube.com/vi/NcC5VCE2Its/mqdefau...
# 1                                                NaN
# 2  https://img.youtube.com/vi/d4EbGC7fKnQ/mqdefau...
# 3                                                NaN
# 4                                                NaN
#
#                       trailer.images.large_image_url  \
# 0  https://img.youtube.com/vi/NcC5VCE2Its/hqdefau...
# 1                                                NaN
# 2  https://img.youtube.com/vi/d4EbGC7fKnQ/hqdefau...
# 3                                                NaN
# 4                                                NaN
#
#                     trailer.images.maximum_image_url  \
# 0  https://img.youtube.com/vi/NcC5VCE2Its/maxresd...
# 1                                                NaN
# 2  https://img.youtube.com/vi/d4EbGC7fKnQ/maxresd...
# 3                                                NaN
# 4                                                NaN
#
#                   aired.from                   aired.to  aired.prop.from.day  \
# 0  2006-04-05T00:00:00+00:00  2006-09-27T00:00:00+00:00                    5
# 1  2006-04-04T00:00:00+00:00  2010-03-25T00:00:00+00:00                    4
# 2  2006-04-09T00:00:00+00:00  2006-06-25T00:00:00+00:00                    9
# 3  2006-04-03T00:00:00+00:00  2006-07-03T00:00:00+00:00                    3
# 4  2006-04-05T00:00:00+00:00  2006-09-27T00:00:00+00:00                    5
#
#    aired.prop.from.month  aired.prop.from.year  aired.prop.to.day  \
# 0                      4                  2006               27.0
# 1                      4                  2006               25.0
# 2                      4                  2006               25.0
# 3                      4                  2006                3.0
# 4                      4                  2006               27.0
#
#    aired.prop.to.month  aired.prop.to.year                 aired.string  \
# 0                  9.0              2006.0  Apr 5, 2006 to Sep 27, 2006
# 1                  3.0              2010.0  Apr 4, 2006 to Mar 25, 2010
# 2                  6.0              2006.0  Apr 9, 2006 to Jun 25, 2006
# 3                  7.0              2006.0   Apr 3, 2006 to Jul 3, 2006
# 4                  9.0              2006.0  Apr 5, 2006 to Sep 27, 2006
#
#   broadcast.day broadcast.time broadcast.timezone           broadcast.string
# 0    Wednesdays          00:50         Asia/Tokyo  Wednesdays at 00:50 (JST)
# 1     Thursdays          18:00         Asia/Tokyo   Thursdays at 18:00 (JST)
# 2       Sundays          02:35         Asia/Tokyo     Sundays at 02:35 (JST)
# 3       Mondays          00:00         Asia/Tokyo     Mondays at 00:00 (JST)
# 4    Wednesdays          01:30         Asia/Tokyo  Wednesdays at 01:30 (JST)

# %% [markdown]
# Check the shape of the data.

# %%
animes.shape
# Out:
# (16337, 59)

# %% [markdown]
# List the columns from the data.

# %%
animes.columns
# Out:
# Index(['mal_id', 'url', 'approved', 'titles', 'title', 'title_english',
#        'title_japanese', 'title_synonyms', 'type', 'source', 'episodes',
#        'status', 'airing', 'duration', 'rating', 'score', 'scored_by', 'rank',
#        'popularity', 'members', 'favorites', 'synopsis', 'background',
#        'season', 'year', 'producers', 'licensors', 'studios', 'genres',
#        'explicit_genres', 'themes', 'demographics', 'images.jpg.image_url',
#        'images.jpg.small_image_url', 'images.jpg.large_image_url',
#        'images.webp.image_url', 'images.webp.small_image_url',
#        'images.webp.large_image_url', 'trailer.youtube_id', 'trailer.url',
#        'trailer.embed_url', 'trailer.images.image_url',
#        'trailer.images.small_image_url', 'trailer.images.medium_image_url',
#        'trailer.images.large_image_url', 'trailer.images.maximum_image_url',
#        'aired.from', 'aired.to', 'aired.prop.from.day',
#        'aired.prop.from.month', 'aired.prop.from.year', 'aired.prop.to.day',
#        'aired.prop.to.month', 'aired.prop.to.year', 'aired.string',
#        'broadcast.day', 'broadcast.time', 'broadcast.timezone',
#        'broadcast.string'],
#       dtype='object')

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ### Dropping the unnecessary columns
#
# Remove irrelevant columns from `animes`.

# %%
columns_to_drop = [
    'approved',
    'titles',
    'year',
    'explicit_genres',
    'images.jpg.small_image_url',
    'images.jpg.large_image_url',
    'images.webp.image_url',
    'images.webp.small_image_url',
    'images.webp.large_image_url',
    'trailer.youtube_id',
    'trailer.embed_url',
    'trailer.images.image_url',
    'trailer.images.small_image_url',
    'trailer.images.medium_image_url',
    'trailer.images.large_image_url',
    'trailer.images.maximum_image_url',
    'aired.from',
    'aired.to',
    'aired.prop.from.day',
    'aired.prop.from.month',
    'aired.prop.to.day',
    'aired.prop.to.month',
    'aired.prop.to.year',
    'broadcast.day', 
    'broadcast.time', 
    'broadcast.timezone'
]

animes.drop(columns=columns_to_drop, inplace=True)

# %% [markdown]
# ### Renaming Columns
#
# Let's rename some colums to get better understaing when we read.

# %%
col_mapping = {
    'images.jpg.image_url': 'image_url',
    'trailer.url': 'trailer_url',
    'aired.prop.from.year' : 'year',
    'aired.string': 'aired_date',
    'broadcast.string': 'broadcast_day_and_time'
}

animes.rename(columns=col_mapping, inplace=True)

# %% [markdown]
# ### Finding numeric columns
#
# Checking which columns are numeric.

# %%
animes.select_dtypes(include='float64').columns
# Out:
# Index(['episodes', 'score', 'scored_by', 'rank'], dtype='object')

# %%
# float_cols = ['episodes', 'scored_by', 'rank']

# for col in float_cols:
#     # animes[col] = animes[col].astype(int)

#     # second method won't work as there are NaN values in the columns
#     # animes[col] = pd.to_numeric(animes[col], errors='coerce').astype(int)

#     # animes[col] = animes[col].fillna(0).astype(int)

# %% [markdown]
# ### Modifying values in some columns
#
# Some columns have values in the form of a list string of multiple dictionaries.
#
# We will convert it into the comma separated string to read and use easily.

# %% [markdown]
# Function: `custom_str_list_to_desrired_str(value, key):`
# - The function requires two parameters: `value` and `key`.
#     - `value` parameter takes the value from the associated column.
#     - `key` parameter takes which value of the key to get from the `value` string.
# - The function performs changing the list string of `value` to the actual list and return comma-separated string of joining from `key`'s value.

# %%
def custom_str_list_to_desrired_str(value, key):
    # converting list string into the list
    data_list = ast.literal_eval(value)
    string = ','.join(genre[key] for genre in data_list)
    return string

# %% [markdown]
# Call the `custom_str_list_to_desrired_str()` function on the columns needed to modify.

# %%
need_to_modify_columns = [
    'producers',
    'licensors',
    'studios',
    'genres',
    'themes',
    'demographics'
]

for col in need_to_modify_columns:
    animes[col] = animes[col].apply(custom_str_list_to_desrired_str, args=('name', ))

animes['title_synonyms'] = animes['title_synonyms'].apply(lambda titles: ','.join(title for title in ast.literal_eval(titles)))

# %% [markdown]
# ### Chcecking total null values
#
# Let's check how many total `NaN` values there are in columns having null values.

# %%
columns_with_nulls = animes.columns[animes.isnull().any()]
col_sum = []
for col in columns_with_nulls:
    col_sum.append(animes[col].isnull().sum())

null_having_columns = list(zip(columns_with_nulls, col_sum))
null_having_columns

null_having_columns_df = pd.DataFrame(null_having_columns, columns=['column_name', 'total_null_values'])
null_having_columns_df.set_index('column_name', inplace=True)
null_having_columns_df.sort_values(by='total_null_values' ,ascending=False, inplace=True)
null_having_columns_df
# Out:
#                         total_null_values
# column_name
# background                          14489
# season                              12676
# trailer_url                         12597
# broadcast_day_and_time              11304
# title_english                        9202
# score                                5550
# scored_by                            5550
# rank                                 3607
# synopsis                             3091
# rating                                147
# episodes                              146
# title_japanese                         58

# %% [markdown]
# ### Filling on the empty string
#
# The values of some columns needs to be filled as those columns will be used as the category to filter the data.
#
# Here, we will empty string with `Others` as a value.

# %%
cols_having_empty_string = ['producers', 'licensors', 'studios', 'genres', 'themes', 'demographics']
animes[cols_having_empty_string] = animes[cols_having_empty_string].replace('', 'Others')

# %% [markdown]
# ### Handling missing values
#
# Some values from the `season` column are missing. Therefore, re-calculating its season from `aired_date` column and update `season`.

# %%
# extracting from aired_date column to get start_date
date_pattern = r'(\w{3} \d{1,2}, \d{4})'
animes['start_date'] = animes['aired_date'].str.extract(date_pattern)
animes['start_date'] = pd.to_datetime(animes['start_date'])

def get_season(month):
    if 4 <= month <= 6:
        return 'Spring'
    elif 7 <= month <= 9:
        return 'Summer'
    elif 10 <= month <= 12:
        return 'Fall'
    else:
        return 'Winter'

# Apply the function to update a 'season' column
animes['season'] = animes['start_date'].dt.month.apply(get_season)

# %% [markdown]
# ### Changing title value
#
# We want the `title` value to be in English if it has the value in `title_english`. If not, then leave `title` value as it is.

# %%
animes['title'] = np.where(
    animes['title_english'].notnull(),
    animes['title_english'],
    animes['title']
)

# %% [markdown]
# # Data Structuring

# %% [markdown]
# In order to improve readablity, `year` column is moved to before `season` column.

# %%
animes.insert(animes.columns.get_loc('season'), 'year', animes.pop('year'))

# %% [markdown]
# Some values from `year` includes the data from `2005`. Therefore, we will filter out those data as they are not included in our project range.

# %%
animes[animes['year'] == 2005]
# Out:
#      mal_id                                                url  \
# 377     558         https://myanimelist.net/anime/558/Major_S2
# 422    2285            https://myanimelist.net/anime/2285/DICE
# 473   27451  https://myanimelist.net/anime/27451/Porong_Por...
# 498   44167    https://myanimelist.net/anime/44167/Meng_Li_Ren
# 523   53910  https://myanimelist.net/anime/53910/Minami_no_...
#
#                                          title                title_english  \
# 377                                   Major S2                          NaN
# 422                                   D.I.C.E.                          NaN
# 473                Pororo the Little Penguin 2  Pororo the Little Penguin 2
# 498                          The Dreaming Girl            The Dreaming Girl
# 523  Minami no Shima no Chiisana Hikouki Birdy                          NaN
#
#        title_japanese                                     title_synonyms type  \
# 377     メジャー (第2シリーズ)                                                      TV
# 422          ディノブレイカー  DICE,DNA Integrated Cybernetic Enterprises,DIN...   TV
# 473        뽀롱뽀롱 뽀로로 2                                                      TV
# 498               夢裡人                                                      TV
# 523  南の島の小さな飛行機 バーディー                                                      TV
#
#        source  episodes           status  airing       duration  \
# 377     Manga      26.0  Finished Airing   False  25 min per ep
# 422  Original      40.0  Finished Airing   False  25 min per ep
# 473  Original      52.0  Finished Airing   False   5 min per ep
# 498   Unknown      26.0  Finished Airing   False  22 min per ep
# 523  Original     105.0  Finished Airing   False  10 min per ep
#
#                         rating  score  scored_by     rank  popularity  \
# 377  PG-13 - Teens 13 or older   8.19    45031.0    373.0        2506
# 422              PG - Children   6.34     2389.0   7550.0        8361
# 473               G - All Ages   5.71      215.0  10499.0       15262
# 498               G - All Ages    NaN        NaN  16044.0       18665
# 523              PG - Children    NaN        NaN  16158.0       23150
#
#      members  favorites                                           synopsis  \
# 377    71263        315  Gorou Honda has finally returned to Mifune Eas...
# 422     4940         19  DICE (DNA Integrated Cybernetic Enterprises) i...
# 473      552          0  A direct continuation of the previous season t...
# 498      266          1                                                NaN
# 523       74          0  This is Bird Paradise Island, a small island i...
#
#     background  year season                            producers  \
# 377        NaN  2005   Fall  Shogakukan-Shueisha Productions,NHK
# 422        NaN  2005   Fall                               Others
# 473        NaN  2005   Fall                               Others
# 498        NaN  2005   Fall                               Others
# 523        NaN  2005   Fall                                  NHK
#
#                 licensors        studios                   genres  \
# 377                Others  Studio Hibari                   Sports
# 422  Bandai Entertainment          Xebec  Action,Adventure,Sci-Fi
# 473                Others         Others                   Others
# 498                Others         Others                    Drama
# 523                Others    Studio Deen                Adventure
#
#               themes demographics  \
# 377      Team Sports      Shounen
# 422            Mecha         Kids
# 473           Others         Kids
# 498           Others       Others
# 523  Anthropomorphic         Kids
#
#                                              image_url trailer_url  \
# 377  https://cdn.myanimelist.net/images/anime/6/739...         NaN
# 422  https://cdn.myanimelist.net/images/anime/1/252...         NaN
# 473  https://cdn.myanimelist.net/images/anime/12/66...         NaN
# 498  https://cdn.myanimelist.net/images/anime/1775/...         NaN
# 523  https://cdn.myanimelist.net/images/anime/1085/...         NaN
#
#                        aired_date    broadcast_day_and_time start_date
# 377  Dec 10, 2005 to Jun 10, 2006                   Unknown 2005-12-10
# 422   Dec 6, 2005 to Sep 19, 2006                   Unknown 2005-12-06
# 473   Dec 3, 2005 to May 28, 2006                   Unknown 2005-12-03
# 498   Dec 12, 2005 to Jan 6, 2006                   Unknown 2005-12-12
# 523   Dec 26, 2005 to Apr 2, 2007  Saturdays at 17:50 (JST) 2005-12-26

# %%
animes = animes[~(animes['year'] == 2005)]

# validating to ensure year 2005 not being in the data anymore
animes['year'].unique()
# Out:
# array([2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016,
#        2017, 2018, 2019, 2020, 2021, 2022])

# %% [markdown]
# Function: `is_subset(value, check_list):`
# - The function requires two parameters: `value` and `check_list`.
#     - `value` parameter takes the value from the associated column.
#     - `check_list` parameter takes to check the list with the `value` string.
# - The function performs changing the `value` string into list and return `True` if `any` of the list string includes in `check_list`, otherwise `False`

# %%
def is_subset(value, check_list):
    value_list = value.split(',')
    return any(value in check_list for value in value_list)

# %% [markdown]
# We will exclude R-18+ genre from the data which is not suitable.

# %%
animes = animes[~(animes['genres'].apply(is_subset, args=(['Hentai'],)))]

# %% [markdown]
# # Data Exploring

# %% [markdown]
# Let's explore the data again after cleaning, transforming and structuring.

# %%
animes.head()
# Out:
#    mal_id                                                url  \
# 0     853  https://myanimelist.net/anime/853/Ouran_Koukou...
# 1     918          https://myanimelist.net/anime/918/Gintama
# 2     889     https://myanimelist.net/anime/889/Black_Lagoon
# 3     849  https://myanimelist.net/anime/849/Suzumiya_Har...
# 4     934  https://myanimelist.net/anime/934/Higurashi_no...
#
#                                title                      title_english  \
# 0        Ouran High School Host Club        Ouran High School Host Club
# 1                            Gintama                            Gintama
# 2                       Black Lagoon                       Black Lagoon
# 3  The Melancholy of Haruhi Suzumiya  The Melancholy of Haruhi Suzumiya
# 4           Higurashi: When They Cry           Higurashi: When They Cry
#
#   title_japanese                                     title_synonyms type  \
# 0       桜蘭高校ホスト部  Ohran Koko Host Club,Ouran Koukou Hosutobu,Our...   TV
# 1             銀魂          Gin Tama,Silver Soul,Yorinuki Gintama-san   TV
# 2   BLACK LAGOON                                                      TV
# 3       涼宮ハルヒの憂鬱                         Suzumiya Haruhi no Yuuutsu   TV
# 4      ひぐらしのなく頃に    When the Cicadas Cry,The Moment the Cicadas Cry   TV
#
#          source  episodes           status  airing       duration  \
# 0         Manga      26.0  Finished Airing   False  23 min per ep
# 1         Manga     201.0  Finished Airing   False  24 min per ep
# 2         Manga      12.0  Finished Airing   False  23 min per ep
# 3   Light novel      14.0  Finished Airing   False  23 min per ep
# 4  Visual novel      26.0  Finished Airing   False  24 min per ep
#
#                            rating  score  scored_by   rank  popularity  \
# 0       PG-13 - Teens 13 or older   8.16   672279.0  413.0         128
# 1       PG-13 - Teens 13 or older   8.94   391827.0   15.0         139
# 2  R - 17+ (violence & profanity)   8.03   487522.0  573.0         155
# 3       PG-13 - Teens 13 or older   7.83   475447.0  888.0         179
# 4  R - 17+ (violence & profanity)   7.88   391899.0  809.0         229
#
#    members  favorites                                           synopsis  \
# 0  1110503      34094  Haruhi Fujioka is a studious girl who has rece...
# 1  1052162      58905  Edo is a city that was home to the vigor and a...
# 2   993437      18516  Salaryman Rokurou Okajima spends his days tryi...
# 3   909771      15321  If a survey were conducted to see if people be...
# 4   797940      21247  Keiichi Maebara has just moved to the quiet li...
#
#                                           background  year  season  \
# 0  In addition to this anime and the source manga...  2006  Spring
# 1  Several games based on Gintama have been relea...  2006  Spring
# 2  Black Lagoon was released on DVD by Geneon Ent...  2006  Spring
# 3  Suzumiya Haruhi no Yuuutsu aired in a nonlinea...  2006  Spring
# 4  Geneon Entertainment USA initially licensed an...  2006  Spring
#
#                                            producers  \
# 0           VAP,Hakusensha,Nippon Television Network
# 1  TV Tokyo,Aniplex,Dentsu,Trinity Sound,Audio Hi...
# 2  Geneon Universal Entertainment,Shogakukan-Shue...
# 3  Lantis,Kadokawa Shoten,Kadokawa Pictures Japan...
# 4  Geneon Universal Entertainment,Frontier Works,...
#
#                                            licensors          studios  \
# 0                                         Funimation            Bones
# 1                       Sentai Filmworks,Crunchyroll          Sunrise
# 2                Funimation,Geneon Entertainment USA         Madhouse
# 3  Funimation,Bandai Entertainment,Kadokawa Pictu...  Kyoto Animation
# 4          Sentai Filmworks,Geneon Entertainment USA      Studio Deen
#
#                                 genres                               themes  \
# 0                       Comedy,Romance   Crossdressing,Reverse Harem,School
# 1                 Action,Comedy,Sci-Fi  Gag Humor,Historical,Parody,Samurai
# 2                               Action           Adult Cast,Organized Crime
# 3  Award Winning,Comedy,Mystery,Sci-Fi                               School
# 4          Horror,Mystery,Supernatural                   Gore,Psychological
#
#   demographics                                          image_url  \
# 0       Shoujo  https://cdn.myanimelist.net/images/anime/2/719...
# 1      Shounen  https://cdn.myanimelist.net/images/anime/10/73...
# 2       Seinen  https://cdn.myanimelist.net/images/anime/1906/...
# 3       Others  https://cdn.myanimelist.net/images/anime/1470/...
# 4       Others  https://cdn.myanimelist.net/images/anime/12/19...
#
#                                    trailer_url                   aired_date  \
# 0  https://www.youtube.com/watch?v=NcC5VCE2Its  Apr 5, 2006 to Sep 27, 2006
# 1                                          NaN  Apr 4, 2006 to Mar 25, 2010
# 2  https://www.youtube.com/watch?v=d4EbGC7fKnQ  Apr 9, 2006 to Jun 25, 2006
# 3                                          NaN   Apr 3, 2006 to Jul 3, 2006
# 4                                          NaN  Apr 5, 2006 to Sep 27, 2006
#
#       broadcast_day_and_time start_date
# 0  Wednesdays at 00:50 (JST) 2006-04-05
# 1   Thursdays at 18:00 (JST) 2006-04-04
# 2     Sundays at 02:35 (JST) 2006-04-09
# 3     Mondays at 00:00 (JST) 2006-04-03
# 4  Wednesdays at 01:30 (JST) 2006-04-05

# %%
animes.shape
# Out:
# (15450, 34)

# %% [markdown]
# ### Checking data types of columns
#
# The `info()` function allows us to check data types of each column easily.

# %%
animes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 15450 entries, 0 to 16336
# Data columns (total 34 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   mal_id                  15450 non-null  int64
#  1   url                     15450 non-null  object
#  2   title                   15450 non-null  object
#  3   title_english           6944 non-null   object
#  4   title_japanese          15394 non-null  object
#  5   title_synonyms          15450 non-null  object
#  6   type                    15450 non-null  object
#  7   source                  15450 non-null  object
#  8   episodes                15317 non-null  float64
#  9   status                  15450 non-null  object
#  10  airing                  15450 non-null  bool
#  11  duration                15450 non-null  object
#  12  rating                  15303 non-null  object
#  13  score                   9902 non-null   float64
#  14  scored_by               9902 non-null   float64
#  15  rank                    12725 non-null  float64
#  16  popularity              15450 non-null  int64
#  17  members                 15450 non-null  int64
#  18  favorites               15450 non-null  int64
#  19  synopsis                12509 non-null  object
#  20  background              1817 non-null   object
#  21  year                    15450 non-null  int64
#  22  season                  15450 non-null  object
#  23  producers               15450 non-null  object
#  24  licensors               15450 non-null  object
#  25  studios                 15450 non-null  object
#  26  genres                  15450 non-null  object
#  27  themes                  15450 non-null  object
#  28  demographics            15450 non-null  object
#  29  image_url               15450 non-null  object
#  30  trailer_url             3723 non-null   object
#  31  aired_date              15450 non-null  object
#  32  broadcast_day_and_time  5028 non-null   object
#  33  start_date              13365 non-null  datetime64[ns]
# dtypes: bool(1), datetime64[ns](1), float64(4), int64(5), object(23)
# memory usage: 4.0+ MB

# %% [markdown]
# ### Finding the descriptive statistics
#
# The `describe()` function can help us to find the descriptive statistics and structure of the numeric columns in the dataset.

# %%
animes.describe()
# Out:
#              mal_id      episodes        score     scored_by          rank  \
# count  15450.000000  15317.000000  9902.000000  9.902000e+03  12725.000000
# mean   35225.594498     14.280734     6.481127  4.279147e+04  10020.081965
# min      356.000000      1.000000     2.330000  1.010000e+02      2.000000
# 25%    27893.000000      1.000000     5.810000  3.500000e+02   4639.000000
# 50%    38250.500000      3.000000     6.470000  2.349000e+03   9965.000000
# 75%    47205.250000     13.000000     7.170000  2.096875e+04  15382.000000
# max    57879.000000   1664.000000     9.090000  2.754086e+06  20440.000000
# std    15331.733933     34.649701     0.918981  1.445766e+05   6062.907524
#
#          popularity       members      favorites          year  \
# count  15450.000000  1.545000e+04   15450.000000  15450.000000
# mean   12947.674628  5.265129e+04     593.087055   2015.141942
# min        1.000000  1.700000e+01       0.000000   2006.000000
# 25%     5179.250000  1.840000e+02       0.000000   2012.000000
# 50%    13546.000000  8.980000e+02       1.000000   2016.000000
# 75%    20146.750000  1.630575e+04      24.000000   2019.000000
# max    26089.000000  3.880951e+06  223131.000000   2022.000000
# std     8020.960102  1.951733e+05    5153.888009      4.574070
#
#                           start_date
# count                          13365
# mean   2015-12-13 18:11:39.797979904
# min              2006-01-01 00:00:00
# 25%              2012-07-21 00:00:00
# 50%              2016-07-11 00:00:00
# 75%              2019-10-02 00:00:00
# max              2023-10-28 00:00:00
# std                              NaN

# %% [markdown]
# Function: `get_category_count_from_str(col):`
# - The function requires one parameter: `col`.
#     - `col` parameter takes the input column of the data.
# - The function performs counting of each value as category from the comma separated string of the `col` column.
# - The function returns `Series` of the category count.

# %%
def get_category_count_from_str(col):
    cat_df = col.str.split(',', expand=True).stack().str.strip()
    # print(cat_df.unique())
    cat_df = pd.get_dummies(cat_df, prefix='', prefix_sep='')

    cat_counts = cat_df.sum(axis=0)

    return cat_counts.sort_values(ascending=False)

# %%
get_category_count_from_str(animes['genres'])
# Out:
# Comedy           4744
# Fantasy          3571
# Others           3236
# Action           2967
# Adventure        2009
# Sci-Fi           1611
# Drama            1454
# Slice of Life    1217
# Romance          1170
# Supernatural      959
# Mystery           584
# Avant Garde       556
# Ecchi             545
# Sports            431
# Horror            290
# Suspense          206
# Gourmet           133
# Award Winning     130
# Boys Love         102
# Girls Love         65
# Erotica            56
# dtype: int64

# %%
get_category_count_from_str(animes['themes'])
# Out:
# Others               5896
# Music                3033
# School               1478
# Historical            787
# Anthropomorphic       678
# Parody                592
# Mecha                 588
# Super Power           476
# Military              412
# Adult Cast            370
# Mythology             359
# Martial Arts          344
# Harem                 317
# Psychological         282
# Strategy Game         267
# Idols (Female)        264
# Space                 262
# CGDCT                 215
# Isekai                211
# Mahou Shoujo          202
# Detective             175
# Team Sports           169
# Racing                166
# Gore                  161
# Gag Humor             157
# Iyashikei             148
# Idols (Male)          147
# Workplace             145
# Samurai               133
# Educational           124
# Vampire               115
# Video Game            112
# Time Travel            99
# Performing Arts        86
# Survival               80
# Otaku Culture          79
# Reincarnation          73
# Reverse Harem          68
# Visual Arts            66
# Love Polygon           62
# Pets                   54
# Childcare              44
# Organized Crime        43
# Romantic Subtext       41
# High Stakes Game       38
# Crossdressing          34
# Medical                27
# Combat Sports          27
# Showbiz                25
# Delinquents            20
# Magical Sex Shift      14
# dtype: int64

# %%
get_category_count_from_str(animes['demographics'])
# Out:
# Others     9979
# Kids       3477
# Shounen    1043
# Seinen      641
# Shoujo      209
# Josei       115
# dtype: int64

# %%
# changing duplicate titles with title synonyms and null titles with english and japanese
animes.loc[animes['title'].duplicated(), 'title'] = animes.loc[animes['title'].duplicated(), 'title_synonyms']
animes.loc[animes['title'].apply(lambda x: x == ''), 'title'] = animes.loc[animes['title'].apply(lambda x: x == ''), 'title_english']
animes.loc[animes['title'].apply(lambda x: x == ''), 'title'] = animes.loc[animes['title'].apply(lambda x: x == ''), 'title_japanese']
animes.loc[animes['title'].isnull(), 'title'] = animes.loc[animes['title'].isnull(), 'title_english']
animes.loc[animes['title'].isnull(), 'title'] = animes.loc[animes['title'].isnull(), 'title_japanese']

# %%
animes[animes['title'].isnull()]
# Out:
# Empty DataFrame
# Columns: [mal_id, url, title, title_english, title_japanese, title_synonyms, type, source, episodes, status, airing, duration, rating, score, scored_by, rank, popularity, members, favorites, synopsis, background, year, season, producers, licensors, studios, genres, themes, demographics, image_url, trailer_url, aired_date, broadcast_day_and_time, start_date]
# Index: []

# %%
dummy = animes.loc[animes['title'].duplicated(), ['title', 'mal_id']]
dummy['title'] = dummy['title'] + '_' + dummy['mal_id'].apply(lambda x: str(x))
animes.loc[animes['title'].duplicated(keep=False), 'title'] = dummy['title']

# %%
animes.loc[animes['title'].isnull(), 'title'] = animes.loc[animes['title'].isnull(), 'title_english']
animes.loc[animes['title'].isnull(), 'title'] = animes.loc[animes['title'].isnull(), 'title_japanese']

# %%
animes[animes['title'].duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [mal_id, url, title, title_english, title_japanese, title_synonyms, type, source, episodes, status, airing, duration, rating, score, scored_by, rank, popularity, members, favorites, synopsis, background, year, season, producers, licensors, studios, genres, themes, demographics, image_url, trailer_url, aired_date, broadcast_day_and_time, start_date]
# Index: []

# %%
animes[animes['title'].isnull()]
# Out:
# Empty DataFrame
# Columns: [mal_id, url, title, title_english, title_japanese, title_synonyms, type, source, episodes, status, airing, duration, rating, score, scored_by, rank, popularity, members, favorites, synopsis, background, year, season, producers, licensors, studios, genres, themes, demographics, image_url, trailer_url, aired_date, broadcast_day_and_time, start_date]
# Index: []

# %% [markdown]
# # Exporting the DataFrame

# %% [markdown]
# Let's export the cleaned data frame as the CSV file to use in the future process.

# %%
animes.to_csv('anime_data_2006_2022_cleaned.csv', index=False)

# %% [markdown]
# # Summary

# %% [markdown]
# In this notebook, we made EDA process: discovering, structuring, cleaning and validating. Then we explore how the data is structured, which categories of genres, demographics, themes are popular and finally we exported cleaned data as CSV file.
#
# In the next part, we will construct an interactive web application.
